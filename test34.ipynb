# %% [markdown]
# ### Test notebook to run Jupyter into docker

# %%
import numpy as np
import matplotlib.image as image
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import griddata

import colorspacious

# %% [markdown]
# ## Mini demo
#
# Here we load an image. Made a copy of it and shuffle the channel order to change the colors.

# %%
img = image.imread('albinocrocodile.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)

img2 = img.copy();
img2 = img[:,:,np.array([2,0,1])]
plt.figure(figsize=(10,8))
plt.imshow(img2)
